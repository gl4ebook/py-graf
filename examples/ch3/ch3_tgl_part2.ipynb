# %%
import networkx as nx
import pandas as pd


# Load CSV files
edges_df = pd.read_csv('amzn_directed_graph.csv')
products_df = pd.read_csv('products.csv')

# Dropping NAs in the data
products_df = products_df.dropna()


# Create a directed graph
G = nx.DiGraph()

# Add nodes from the products dataframe
for idx, row in products_df.iterrows():
    G.add_node(row['Id'], 
               ASIN=row['ASIN'],
               title=row['title'],
               group=row['group'],
               salesrank=row['salesrank'],
               similar=row['similar'],
               categories=row['categories'],
               total_reviews=row['total_reviews'],
               avg_rating=row['avg_rating'])

# Add edges from the edges dataframe
for idx, row in edges_df.iterrows():
    G.add_edge(row['FromNodeId'], row['ToNodeId'])

# %%
reference_nodes = list(G.nodes())[:2]  # Using the first 5 nodes as reference
shortest_path_features = {}

for node in G.nodes():
    shortest_path_features[node] = []
    for ref_node in reference_nodes:
        try:
            shortest_path_features[node].append(nx.shortest_path_length(G, node, ref_node))
        except nx.NetworkXNoPath:
            shortest_path_features[node].append(float('inf'))

# %%
shortest_path_features
# Out:
# {1: [0, 1],
#  2: [2, 0],
#  4: [inf, inf],
#  5: [inf, inf],
#  6: [inf, inf],
#  7: [inf, inf],
#  8: [inf, inf],
#  10: [inf, inf],
#  11: [inf, inf],
#  12: [inf, inf],
#  15: [inf, inf],
#  16: [inf, inf],
#  17: [inf, inf],
#  18: [inf, inf],
#  19: [inf, inf],
#  20: [inf, inf],
#  21: [inf, inf],
#  22: [inf, inf],
#  25: [inf, inf],
#  26: [inf, inf],
#  27: [inf, inf],
#  28: [inf, inf],
#  29: [inf, inf],
#  30: [inf, inf],
#  31: [inf, inf],
#  32: [inf, inf],
#  33: [inf, inf],
#  34: [inf, inf],
#  35: [inf, inf],
#  37: [inf, inf],
#  38: [inf, inf],
#  39: [inf, inf],
#  42: [inf, inf],
#  43: [inf, inf],
#  44: [inf, inf],
#  45: [inf, inf],
#  46: [inf, inf],
#  47: [inf, inf],
#  48: [inf, inf],
#  50: [inf, inf],
#  51: [inf, inf],
#  52: [inf, inf],
#  54: [inf, inf],
#  59: [inf, inf],
#  60: [inf, inf],
#  62: [inf, inf],
#  63: [inf, inf],
#  64: [inf, inf],
#  65: [inf, inf],
#  66: [inf, inf],
#  68: [inf, inf],
#  69: [inf, inf],
#  71: [inf, inf],
#  72: [inf, inf],
#  73: [inf, inf],
#  74: [inf, inf],
#  75: [inf, inf],
#  77: [inf, inf],
#  78: [inf, inf],
#  79: [inf, inf],
#  80: [inf, inf],
#  81: [inf, inf],
#  82: [inf, inf],
#  84: [inf, inf],
#  87: [inf, inf],
#  90: [inf, inf],
#  91: [inf, inf],
#  92: [inf, inf],
#  94: [inf, inf],
#  96: [inf, inf],
#  97: [inf, inf],
#  98: [inf, inf],
#  99: [inf, inf],
#  100: [inf, inf],
#  101: [inf, inf],
#  102: [inf, inf],
#  103: [inf, inf],
#  104: [inf, inf],
#  105: [inf, inf],
#  107: [inf, inf],
#  108: [inf, inf],
#  109: [inf, inf],
#  110: [inf, inf],
#  117: [inf, inf],
#  118: [inf, inf],
#  119: [inf, inf],
#  120: [inf, inf],
#  121: [inf, inf],
#  124: [inf, inf],
#  125: [inf, inf],
#  127: [inf, inf],
#  128: [inf, inf],
#  129: [inf, inf],
#  130: [inf, inf],
#  131: [inf, inf],
#  132: [inf, inf],
#  133: [inf, inf],
#  136: [inf, inf],
#  137: [inf, inf],
#  138: [inf, inf],
#  141: [inf, inf],
#  142: [inf, inf],
#  143: [inf, inf],
#  144: [inf, inf],
#  145: [inf, inf],
#  146: [inf, inf],
#  147: [inf, inf],
#  148: [inf, inf],
#  149: [inf, inf],
#  151: [inf, inf],
#  153: [inf, inf],
#  154: [inf, inf],
#  155: [inf, inf],
#  158: [inf, inf],
#  159: [inf, inf],
#  160: [inf, inf],
#  162: [inf, inf],
#  163: [inf, inf],
#  164: [inf, inf],
#  165: [inf, inf],
#  166: [inf, inf],
#  167: [inf, inf],
#  170: [inf, inf],
#  172: [inf, inf],
#  173: [inf, inf],
#  174: [inf, inf],
#  176: [inf, inf],
#  177: [inf, inf],
#  178: [inf, inf],
#  179: [inf, inf],
#  180: [inf, inf],
#  181: [inf, inf],
#  182: [inf, inf],
#  184: [inf, inf],
#  185: [inf, inf],
#  186: [inf, inf],
#  187: [inf, inf],
#  189: [inf, inf],
#  190: [inf, inf],
#  193: [inf, inf],
#  195: [inf, inf],
#  198: [inf, inf],
#  199: [inf, inf],
#  200: [inf, inf],
#  201: [inf, inf],
#  203: [inf, inf],
#  207: [inf, inf],
#  211: [inf, inf],
#  212: [inf, inf],
#  214: [inf, inf],
#  215: [inf, inf],
#  220: [inf, inf],
#  221: [inf, inf],
#  222: [inf, inf],
#  224: [inf, inf],
#  225: [inf, inf],
#  230: [inf, inf],
#  231: [inf, inf],
#  232: [inf, inf],
#  233: [inf, inf],
#  235: [inf, inf],
#  239: [inf, inf],
#  240: [inf, inf],
#  241: [inf, inf],
#  242: [inf, inf],
#  244: [inf, inf],
#  246: [inf, inf],
#  248: [inf, inf],
#  249: [inf, inf],
#  250: [inf, inf],
#  251: [inf, inf],
#  252: [inf, inf],
#  253: [inf, inf],
#  254: [inf, inf],
#  255: [inf, inf],
#  256: [inf, inf],
#  257: [inf, inf],
#  259: [inf, inf],
#  260: [inf, inf],
#  261: [inf, inf],
#  263: [inf, inf],
#  264: [inf, inf],
#  265: [inf, inf],
#  266: [inf, inf],
#  268: [inf, inf],
#  269: [inf, inf],
#  271: [inf, inf],
#  272: [inf, inf],
#  273: [inf, inf],
#  274: [inf, inf],
#  275: [inf, inf],
#  276: [inf, inf],
#  277: [inf, inf],
#  278: [inf, inf],
#  279: [inf, inf],
#  282: [inf, inf],
#  284: [inf, inf],
#  285: [inf, inf],
#  287: [inf, inf],
#  296: [inf, inf],
#  299: [inf, inf],
#  302: [inf, inf],
#  303: [inf, inf],
#  304: [inf, inf],
#  305: [inf, inf],
#  306: [inf, inf],
#  307: [inf, inf],
#  309: [inf, inf],
#  311: [inf, inf],
#  312: [inf, inf],
#  313: [inf, inf],
#  314: [inf, inf],
#  316: [inf, inf],
#  317: [inf, inf],
#  318: [inf, inf],
#  320: [inf, inf],
#  321: [inf, inf],
#  322: [inf, inf],
#  323: [inf, inf],
#  324: [inf, inf],
#  326: [inf, inf],
#  327: [inf, inf],
#  329: [inf, inf],
#  331: [inf, inf],
#  333: [inf, inf],
#  334: [inf, inf],
#  335: [inf, inf],
#  338: [inf, inf],
#  340: [inf, inf],
#  341: [inf, inf],
#  343: [inf, inf],
#  344: [inf, inf],
#  345: [inf, inf],
#  346: [inf, inf],
#  347: [inf, inf],
#  349: [inf, inf],
#  350: [inf, inf],
#  351: [inf, inf],
#  352: [inf, inf],
#  353: [inf, inf],
#  354: [inf, inf],
#  358: [inf, inf],
#  359: [inf, inf],
#  360: [inf, inf],
#  362: [inf, inf],
#  363: [inf, inf],
#  364: [inf, inf],
#  365: [inf, inf],
#  366: [inf, inf],
#  367: [inf, inf],
#  369: [inf, inf],
#  370: [inf, inf],
#  371: [inf, inf],
#  372: [inf, inf],
#  373: [inf, inf],
#  374: [inf, inf],
#  375: [inf, inf],
#  376: [inf, inf],
#  377: [inf, inf],
#  379: [inf, inf],
#  383: [inf, inf],
#  385: [inf, inf],
#  386: [inf, inf],
#  390: [inf, inf],
#  391: [inf, inf],
#  392: [inf, inf],
#  393: [inf, inf],
#  396: [inf, inf],
#  397: [inf, inf],
#  398: [inf, inf],
#  399: [inf, inf],
#  400: [inf, inf],
#  401: [inf, inf],
#  404: [inf, inf],
#  405: [inf, inf],
#  407: [inf, inf],
#  408: [inf, inf],
#  409: [inf, inf],
#  410: [inf, inf],
#  411: [inf, inf],
#  412: [inf, inf],
#  413: [inf, inf],
#  414: [inf, inf],
#  416: [inf, inf],
#  417: [inf, inf],
#  418: [inf, inf],
#  420: [inf, inf],
#  422: [inf, inf],
#  423: [inf, inf],
#  424: [inf, inf],
#  425: [inf, inf],
#  426: [inf, inf],
#  429: [inf, inf],
#  430: [inf, inf],
#  431: [inf, inf],
#  433: [inf, inf],
#  434: [inf, inf],
#  435: [inf, inf],
#  437: [inf, inf],
#  439: [inf, inf],
#  441: [inf, inf],
#  442: [inf, inf],
#  443: [inf, inf],
#  444: [inf, inf],
#  445: [inf, inf],
#  448: [inf, inf],
#  450: [inf, inf],
#  451: [inf, inf],
#  453: [inf, inf],
#  455: [inf, inf],
#  456: [inf, inf],
#  457: [inf, inf],
#  458: [inf, inf],
#  459: [inf, inf],
#  460: [inf, inf],
#  461: [inf, inf],
#  462: [inf, inf],
#  464: [inf, inf],
#  465: [inf, inf],
#  466: [inf, inf],
#  467: [inf, inf],
#  468: [inf, inf],
#  470: [inf, inf],
#  471: [inf, inf],
#  472: [inf, inf],
#  473: [inf, inf],
#  474: [inf, inf],
#  475: [inf, inf],
#  476: [inf, inf],
#  477: [inf, inf],
#  478: [inf, inf],
#  479: [inf, inf],
#  480: [inf, inf],
#  483: [inf, inf],
#  484: [inf, inf],
#  485: [inf, inf],
#  486: [inf, inf],
#  487: [inf, inf],
#  488: [inf, inf],
#  490: [inf, inf],
#  491: [inf, inf],
#  492: [inf, inf],
#  493: [inf, inf],
#  494: [inf, inf],
#  495: [inf, inf],
#  496: [inf, inf],
#  498: [inf, inf],
#  499: [inf, inf],
#  500: [inf, inf],
#  501: [inf, inf],
#  502: [inf, inf],
#  504: [inf, inf],
#  505: [inf, inf],
#  507: [inf, inf],
#  509: [inf, inf],
#  510: [inf, inf],
#  513: [inf, inf],
#  514: [inf, inf],
#  515: [inf, inf],
#  517: [inf, inf],
#  518: [inf, inf],
#  520: [inf, inf],
#  521: [inf, inf],
#  522: [inf, inf],
#  524: [inf, inf],
#  527: [inf, inf],
#  534: [inf, inf],
#  537: [inf, inf],
#  538: [inf, inf],
#  539: [inf, inf],
#  540: [inf, inf],
#  543: [inf, inf],
#  545: [inf, inf],
#  547: [inf, inf],
#  548: [inf, inf],
#  550: [inf, inf],
#  551: [inf, inf],
#  554: [inf, inf],
#  556: [inf, inf],
#  557: [inf, inf],
#  558: [inf, inf],
#  559: [inf, inf],
#  560: [inf, inf],
#  561: [inf, inf],
#  563: [inf, inf],
#  564: [inf, inf],
#  565: [inf, inf],
#  566: [inf, inf],
#  567: [inf, inf],
#  568: [inf, inf],
#  569: [inf, inf],
#  571: [inf, inf],
#  573: [inf, inf],
#  574: [inf, inf],
#  575: [inf, inf],
#  576: [inf, inf],
#  577: [inf, inf],
#  578: [inf, inf],
#  579: [inf, inf],
#  580: [inf, inf],
#  581: [inf, inf],
#  582: [inf, inf],
#  584: [inf, inf],
#  585: [inf, inf],
#  586: [inf, inf],
#  587: [inf, inf],
#  588: [inf, inf],
#  590: [inf, inf],
#  591: [inf, inf],
#  593: [inf, inf],
#  594: [inf, inf],
#  596: [inf, inf],
#  597: [inf, inf],
#  598: [inf, inf],
#  599: [inf, inf],
#  600: [inf, inf],
#  602: [inf, inf],
#  606: [inf, inf],
#  607: [inf, inf],
#  608: [inf, inf],
#  609: [inf, inf],
#  610: [inf, inf],
#  611: [inf, inf],
#  612: [inf, inf],
#  613: [inf, inf],
#  615: [inf, inf],
#  616: [inf, inf],
#  617: [inf, inf],
#  618: [inf, inf],
#  619: [inf, inf],
#  620: [inf, inf],
#  621: [inf, inf],
#  622: [inf, inf],
#  624: [inf, inf],
#  625: [inf, inf],
#  626: [inf, inf],
#  629: [inf, inf],
#  630: [inf, inf],
#  632: [inf, inf],
#  633: [inf, inf],
#  634: [inf, inf],
#  636: [inf, inf],
#  637: [inf, inf],
#  638: [inf, inf],
#  640: [inf, inf],
#  641: [inf, inf],
#  642: [inf, inf],
#  645: [inf, inf],
#  646: [inf, inf],
#  647: [inf, inf],
#  648: [inf, inf],
#  649: [inf, inf],
#  650: [inf, inf],
#  651: [inf, inf],
#  652: [inf, inf],
#  653: [inf, inf],
#  654: [inf, inf],
#  655: [inf, inf],
#  656: [inf, inf],
#  658: [inf, inf],
#  662: [inf, inf],
#  664: [inf, inf],
#  665: [inf, inf],
#  666: [inf, inf],
#  668: [inf, inf],
#  670: [inf, inf],
#  672: [inf, inf],
#  676: [inf, inf],
#  677: [inf, inf],
#  678: [inf, inf],
#  681: [inf, inf],
#  682: [inf, inf],
#  683: [inf, inf],
#  685: [inf, inf],
#  686: [inf, inf],
#  687: [inf, inf],
#  688: [inf, inf],
#  689: [inf, inf],
#  690: [inf, inf],
#  691: [inf, inf],
#  692: [inf, inf],
#  694: [inf, inf],
#  695: [inf, inf],
#  696: [inf, inf],
#  697: [inf, inf],
#  698: [inf, inf],
#  699: [inf, inf],
#  700: [inf, inf],
#  702: [inf, inf],
#  704: [inf, inf],
#  705: [inf, inf],
#  707: [inf, inf],
#  709: [inf, inf],
#  710: [inf, inf],
#  714: [inf, inf],
#  715: [inf, inf],
#  716: [inf, inf],
#  717: [inf, inf],
#  719: [inf, inf],
#  722: [inf, inf],
#  723: [inf, inf],
#  724: [inf, inf],
#  726: [inf, inf],
#  727: [inf, inf],
#  728: [inf, inf],
#  731: [inf, inf],
#  732: [inf, inf],
#  733: [inf, inf],
#  734: [inf, inf],
#  735: [inf, inf],
#  737: [inf, inf],
#  738: [inf, inf],
#  739: [inf, inf],
#  740: [inf, inf],
#  741: [inf, inf],
#  743: [inf, inf],
#  744: [inf, inf],
#  745: [inf, inf],
#  746: [inf, inf],
#  749: [inf, inf],
#  750: [inf, inf],
#  752: [inf, inf],
#  753: [inf, inf],
#  754: [inf, inf],
#  756: [inf, inf],
#  757: [inf, inf],
#  758: [inf, inf],
#  760: [inf, inf],
#  762: [inf, inf],
#  763: [inf, inf],
#  765: [inf, inf],
#  766: [inf, inf],
#  767: [inf, inf],
#  768: [inf, inf],
#  770: [inf, inf],
#  771: [inf, inf],
#  772: [inf, inf],
#  775: [inf, inf],
#  776: [inf, inf],
#  777: [inf, inf],
#  778: [inf, inf],
#  779: [inf, inf],
#  780: [inf, inf],
#  781: [inf, inf],
#  783: [inf, inf],
#  784: [inf, inf],
#  785: [inf, inf],
#  786: [inf, inf],
#  787: [inf, inf],
#  789: [inf, inf],
#  792: [inf, inf],
#  793: [inf, inf],
#  795: [inf, inf],
#  797: [inf, inf],
#  800: [inf, inf],
#  801: [inf, inf],
#  802: [inf, inf],
#  803: [inf, inf],
#  804: [inf, inf],
#  805: [inf, inf],
#  806: [inf, inf],
#  807: [inf, inf],
#  808: [inf, inf],
#  809: [inf, inf],
#  810: [inf, inf],
#  812: [inf, inf],
#  813: [inf, inf],
#  814: [inf, inf],
#  817: [inf, inf],
#  818: [inf, inf],
#  819: [inf, inf],
#  821: [inf, inf],
#  822: [inf, inf],
#  824: [inf, inf],
#  826: [inf, inf],
#  827: [inf, inf],
#  828: [inf, inf],
#  829: [inf, inf],
#  830: [inf, inf],
#  834: [inf, inf],
#  835: [inf, inf],
#  837: [inf, inf],
#  838: [inf, inf],
#  840: [inf, inf],
#  841: [inf, inf],
#  842: [inf, inf],
#  843: [inf, inf],
#  845: [inf, inf],
#  846: [inf, inf],
#  849: [inf, inf],
#  851: [inf, inf],
#  852: [inf, inf],
#  854: [inf, inf],
#  856: [inf, inf],
#  858: [inf, inf],
#  859: [inf, inf],
#  860: [inf, inf],
#  861: [inf, inf],
#  862: [inf, inf],
#  863: [inf, inf],
#  864: [inf, inf],
#  865: [inf, inf],
#  866: [inf, inf],
#  868: [inf, inf],
#  870: [inf, inf],
#  871: [inf, inf],
#  873: [inf, inf],
#  874: [inf, inf],
#  876: [inf, inf],
#  878: [inf, inf],
#  879: [inf, inf],
#  880: [inf, inf],
#  881: [inf, inf],
#  882: [inf, inf],
#  883: [inf, inf],
#  885: [inf, inf],
#  886: [inf, inf],
#  887: [inf, inf],
#  888: [inf, inf],
#  889: [inf, inf],
#  890: [inf, inf],
#  892: [inf, inf],
#  893: [inf, inf],
#  894: [inf, inf],
#  895: [inf, inf],
#  896: [inf, inf],
#  897: [inf, inf],
#  898: [inf, inf],
#  899: [inf, inf],
#  900: [inf, inf],
#  901: [inf, inf],
#  902: [inf, inf],
#  904: [inf, inf],
#  905: [inf, inf],
#  908: [inf, inf],
#  910: [inf, inf],
#  911: [inf, inf],
#  912: [inf, inf],
#  914: [inf, inf],
#  915: [inf, inf],
#  917: [inf, inf],
#  918: [inf, inf],
#  919: [inf, inf],
#  920: [inf, inf],
#  921: [inf, inf],
#  922: [inf, inf],
#  923: [inf, inf],
#  924: [inf, inf],
#  925: [inf, inf],
#  926: [inf, inf],
#  928: [inf, inf],
#  929: [inf, inf],
#  930: [inf, inf],
#  931: [inf, inf],
#  932: [inf, inf],
#  933: [inf, inf],
#  935: [inf, inf],
#  937: [inf, inf],
#  938: [inf, inf],
#  941: [inf, inf],
#  942: [inf, inf],
#  943: [inf, inf],
#  945: [inf, inf],
#  948: [inf, inf],
#  949: [inf, inf],
#  950: [inf, inf],
#  951: [inf, inf],
#  952: [inf, inf],
#  953: [inf, inf],
#  955: [inf, inf],
#  956: [inf, inf],
#  958: [inf, inf],
#  959: [inf, inf],
#  960: [inf, inf],
#  962: [inf, inf],
#  963: [inf, inf],
#  964: [inf, inf],
#  965: [inf, inf],
#  966: [inf, inf],
#  967: [inf, inf],
#  968: [inf, inf],
#  969: [inf, inf],
#  970: [inf, inf],
#  971: [inf, inf],
#  972: [inf, inf],
#  973: [inf, inf],
#  974: [inf, inf],
#  975: [inf, inf],
#  976: [inf, inf],
#  977: [inf, inf],
#  981: [inf, inf],
#  982: [inf, inf],
#  985: [inf, inf],
#  986: [inf, inf],
#  987: [inf, inf],
#  989: [inf, inf],
#  991: [inf, inf],
#  995: [inf, inf],
#  998: [inf, inf],
#  999: [inf, inf],
#  1000: [inf, inf],
#  1002: [inf, inf],
#  1006: [inf, inf],
#  1008: [inf, inf],
#  1009: [inf, inf],
#  1011: [inf, inf],
#  1014: [inf, inf],
#  1015: [inf, inf],
#  1017: [inf, inf],
#  1019: [inf, inf],
#  1022: [inf, inf],
#  1023: [inf, inf],
#  1025: [inf, inf],
#  1026: [inf, inf],
#  1028: [inf, inf],
#  1032: [inf, inf],
#  1034: [inf, inf],
#  1035: [inf, inf],
#  1036: [inf, inf],
#  1037: [inf, inf],
#  1038: [inf, inf],
#  1039: [inf, inf],
#  1042: [inf, inf],
#  1044: [inf, inf],
#  1046: [inf, inf],
#  1047: [inf, inf],
#  1048: [inf, inf],
#  1049: [inf, inf],
#  1050: [inf, inf],
#  1051: [inf, inf],
#  1052: [inf, inf],
#  1054: [inf, inf],
#  1055: [inf, inf],
#  1057: [inf, inf],
#  1059: [inf, inf],
#  1060: [inf, inf],
#  1065: [inf, inf],
#  1066: [inf, inf],
#  1067: [inf, inf],
#  1070: [inf, inf],
#  1072: [inf, inf],
#  1073: [inf, inf],
#  1074: [inf, inf],
#  1075: [inf, inf],
#  1076: [inf, inf],
#  1077: [inf, inf],
#  1078: [inf, inf],
#  1081: [inf, inf],
#  1083: [inf, inf],
#  1088: [inf, inf],
#  1090: [inf, inf],
#  1091: [inf, inf],
#  1096: [inf, inf],
#  1098: [inf, inf],
#  1100: [inf, inf],
#  1101: [inf, inf],
#  1103: [inf, inf],
#  1105: [inf, inf],
#  1106: [inf, inf],
#  1107: [inf, inf],
#  1110: [inf, inf],
#  1111: [inf, inf],
#  1112: [inf, inf],
#  1113: [inf, inf],
#  1114: [inf, inf],
#  1117: [inf, inf],
#  1118: [inf, inf],
#  1119: [inf, inf],
#  1120: [inf, inf],
#  1122: [inf, inf],
#  1123: [inf, inf],
#  1124: [inf, inf],
#  1125: [inf, inf],
#  1126: [inf, inf],
#  1128: [inf, inf],
#  1130: [inf, inf],
#  1131: [inf, inf],
#  1133: [inf, inf],
#  1134: [inf, inf],
#  1135: [inf, inf],
#  1136: [inf, inf],
#  1137: [inf, inf],
#  1139: [inf, inf],
#  1140: [inf, inf],
#  1141: [inf, inf],
#  1143: [inf, inf],
#  1144: [inf, inf],
#  1145: [inf, inf],
#  1147: [inf, inf],
#  1148: [inf, inf],
#  1151: [inf, inf],
#  1153: [inf, inf],
#  1156: [inf, inf],
#  1157: [inf, inf],
#  1158: [inf, inf],
#  1159: [inf, inf],
#  1160: [inf, inf],
#  1162: [inf, inf],
#  1163: [inf, inf],
#  1164: [inf, inf],
#  1165: [inf, inf],
#  1166: [inf, inf],
#  1167: [inf, inf],
#  1169: [inf, inf],
#  1170: [inf, inf],
#  1172: [inf, inf],
#  1173: [inf, inf],
#  1174: [inf, inf],
#  1175: [inf, inf],
#  1177: [inf, inf],
#  1178: [inf, inf],
#  1179: [inf, inf],
#  1180: [inf, inf],
#  1181: [inf, inf],
#  1183: [inf, inf],
#  1184: [inf, inf],
#  1186: [inf, inf],
#  1187: [inf, inf],
#  1188: [inf, inf],
#  1189: [inf, inf],
#  1192: [inf, inf],
#  1194: [inf, inf],
#  1200: [inf, inf],
#  1201: [inf, inf],
#  1203: [inf, inf],
#  1204: [inf, inf],
#  1205: [inf, inf],
#  1206: [inf, inf],
#  1208: [inf, inf],
#  1209: [inf, inf],
#  1210: [inf, inf],
#  1212: [inf, inf],
#  1213: [inf, inf],
#  1214: [inf, inf],
#  1215: [inf, inf],
#  1218: [inf, inf],
#  1220: [inf, inf],
#  1221: [inf, inf],
#  1223: [inf, inf],
#  1224: [inf, inf],
#  1226: [inf, inf],
#  1227: [inf, inf],
#  1230: [inf, inf],
#  1232: [inf, inf],
#  1235: [inf, inf],
#  1237: [inf, inf],
#  1238: [inf, inf],
#  1239: [inf, inf],
#  1240: [inf, inf],
#  1242: [inf, inf],
#  1245: [inf, inf],
#  1246: [inf, inf],
#  1249: [inf, inf],
#  1250: [inf, inf],
#  1251: [inf, inf],
#  1252: [inf, inf],
#  1255: [inf, inf],
#  1259: [inf, inf],
#  1261: [inf, inf],
#  1262: [inf, inf],
#  1263: [inf, inf],
#  1268: [inf, inf],
#  1269: [inf, inf],
#  1270: [inf, inf],
#  1271: [inf, inf],
#  1272: [inf, inf],
#  1273: [inf, inf],
#  1274: [inf, inf],
#  1275: [inf, inf],
#  1277: [inf, inf],
#  1278: [inf, inf],
#  1279: [inf, inf],
#  1280: [inf, inf],
#  1282: [inf, inf],
#  1283: [inf, inf],
#  1284: [inf, inf],
#  1285: [inf, inf],
#  1287: [inf, inf],
#  1288: [inf, inf],
#  1290: [inf, inf],
#  1291: [inf, inf],
#  1292: [inf, inf],
#  1293: [inf, inf],
#  1295: [inf, inf],
#  1297: [inf, inf],
#  1298: [inf, inf],
#  1299: [inf, inf],
#  1302: [inf, inf],
#  1304: [inf, inf],
#  1306: [inf, inf],
#  1307: [inf, inf],
#  1308: [inf, inf],
#  1309: [inf, inf],
#  1310: [inf, inf],
#  1311: [inf, inf],
#  1312: [inf, inf],
#  1314: [inf, inf],
#  1315: [inf, inf],
#  1316: [inf, inf],
#  1318: [inf, inf],
#  1319: [inf, inf],
#  1321: [inf, inf],
#  1322: [inf, inf],
#  1323: [inf, inf],
#  1324: [inf, inf],
#  1325: [inf, inf],
#  1326: [inf, inf],
#  1328: [inf, inf],
#  1329: [inf, inf],
#  1330: [inf, inf],
#  1331: [inf, inf],
#  1332: [inf, inf],
#  1333: [inf, inf],
#  1334: [inf, inf],
#  1336: [inf, inf],
#  1337: [inf, inf],
#  1338: [inf, inf],
#  1339: [inf, inf],
#  1340: [inf, inf],
#  1342: [inf, inf],
#  1344: [inf, inf],
#  1346: [inf, inf],
#  1348: [inf, inf],
#  1349: [inf, inf],
#  1351: [inf, inf],
#  1352: [inf, inf],
#  1354: [inf, inf],
#  1355: [inf, inf],
#  1356: [inf, inf],
#  1357: [inf, inf],
#  1358: [inf, inf],
#  1359: [inf, inf],
#  1360: [inf, inf],
#  1361: [inf, inf],
#  1362: [inf, inf],
#  1365: [inf, inf],
#  1367: [inf, inf],
#  1370: [inf, inf],
#  1371: [inf, inf],
#  1372: [inf, inf],
#  1373: [inf, inf],
#  1375: [inf, inf],
#  1376: [inf, inf],
#  1377: [inf, inf],
#  1379: [inf, inf],
#  1380: [inf, inf],
#  1382: [inf, inf],
#  1383: [inf, inf],
#  1386: [inf, inf],
#  1387: [inf, inf],
#  1389: [inf, inf],
#  1391: [inf, inf],
#  1392: [inf, inf],
#  1393: [inf, inf],
#  1394: [inf, inf],
#  1395: [inf, inf],
#  1398: [inf, inf],
#  1399: [inf, inf],
#  1401: [inf, inf],
#  1402: [inf, inf],
#  1403: [inf, inf],
#  1404: [inf, inf],
#  1405: [inf, inf],
#  1407: [inf, inf],
#  1408: [inf, inf],
#  1409: [inf, inf],
#  1411: [inf, inf],
#  1413: [inf, inf],
#  1414: [inf, inf],
#  1415: [inf, inf],
#  1418: [inf, inf],
#  1419: [inf, inf],
#  1420: [inf, inf],
#  1421: [inf, inf],
#  1422: [inf, inf],
#  1423: [inf, inf],
#  1425: [inf, inf],
#  1426: [inf, inf],
#  1427: [inf, inf],
#  1429: [inf, inf],
#  1430: [inf, inf],
#  1432: [inf, inf],
#  1433: [inf, inf],
#  1434: [inf, inf],
#  1437: [inf, inf],
#  1438: [inf, inf],
#  1439: [inf, inf],
#  1440: [inf, inf],
#  1441: [inf, inf],
#  1442: [inf, inf],
#  1443: [inf, inf],
#  1444: [inf, inf],
#  1446: [inf, inf],
#  1447: [inf, inf],
#  1448: [inf, inf],
#  1450: [inf, inf],
#  1451: [inf, inf],
#  1452: [inf, inf],
#  1453: [inf, inf],
#  1454: [inf, inf],
#  ...}

# %%
# !pip install node2vec
# Out:
# Collecting node2vec
#   Downloading node2vec-0.4.6-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.19.5 in /Users/amenshawy/opt/anaconda3/lib/python3.9/site-packages (from node2vec) (1.26.1)
# Requirement already satisfied: joblib<2.0.0,>=1.1.0 in /Users/amenshawy/opt/anaconda3/lib/python3.9/site-packages (from node2vec) (1.1.0)
# Requirement already satisfied: gensim<5.0.0,>=4.1.2 in /Users/amenshawy/opt/anaconda3/lib/python3.9/site-packages (from node2vec) (4.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.55.1 in /Users/amenshawy/opt/anaconda3/lib/python3.9/site-packages (from node2vec) (4.64.0)
# Collecting networkx<3.0,>=2.5
#   Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Requirement already satisfied: smart-open>=1.8.1 in /Users/amenshawy/opt/anaconda3/lib/python3.9/site-packages (from gensim<5.0.0,>=4.1.2->node2vec) (5.1.0)
# Requirement already satisfied: scipy>=0.18.1 in /Users/amenshawy/opt/anaconda3/lib/python3.9/site-packages (from gensim<5.0.0,>=4.1.2->node2vec) (1.11.3)
# Installing collected packages: networkx, node2vec
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.1
#     Uninstalling networkx-3.1:
#       Successfully uninstalled networkx-3.1
# Successfully installed networkx-2.8.8 node2vec-0.4.6

# %%
from node2vec import Node2Vec

node2vec = Node2Vec(G, dimensions=64, walk_length=30, num_walks=200, workers=4)
model = node2vec.fit(window=10, min_count=1)

node2vec_features = {}
for node in G.nodes():
    node2vec_features[node] = model.wv[node]
# Out:
# Computing transition probabilities:   0%|          | 0/458167 [00:00<?, ?it/s]
# Generating walks (CPU: 1): 100%|██████████| 50/50 [48:26<00:00, 58.12s/it]
# Generating walks (CPU: 3): 100%|██████████| 50/50 [55:41<00:00, 66.83s/it]
# Generating walks (CPU: 4): 100%|██████████| 50/50 [1:04:38<00:00, 77.57s/it]it]
# Generating walks (CPU: 2): 100%|██████████| 50/50 [1:16:00<00:00, 91.20s/it]

# %%
features_df = pd.DataFrame.from_dict(shortest_path_features, orient='index')
features_df['node2vec'] = features_df.index.map(node2vec_features)
features_df = features_df.join(products_df.set_index('Id'), on=features_df.index)

# %%
features_df = pd.DataFrame.from_dict(shortest_path_features, orient='index')
features_df['node2vec'] = features_df.index.map(node2vec_features)
features_df = features_df.join(products_df.set_index('Id'), on=features_df.index)

# %%
# Convert the node2vec features dictionary to a DataFrame.
features_df = pd.DataFrame.from_dict(node2vec_features, orient='index')

# Join features_df with the products_df
features_df = features_df.join(products_df.set_index('Id'), on=features_df.index)

# only use 'node2vec' column from features_df and salesrank from the original products metadata
X = list(features_df['node2vec'])
X = pd.DataFrame(X)
X['salesrank'] = features_df['salesrank']
